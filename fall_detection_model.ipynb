# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# %pip install -qr yolov5/requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd yolov5

from yolov5 import utils
display = utils.notebook_init()
# Out:
# YOLOv5  v7.0-135-g9dd0ad3 Python-3.9.16 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# Setup complete  (24 CPUs, 31.7 GB RAM, 294.5/953.1 GB disk)

# %%
# hyperparameters for tweaking
thresholds = [0.2, 0.3, 0.4]
learning_rates = [0.001, 0.002, 0.005, 0.01, 0.02, 0.05, 0.1]

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_0.yaml --name exp_0_0
# Out:
# train: weights=yolov5s.pt, cfg=, data=../custom_data.yaml, hyp=../data/hyps/hyp_0_0.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../runs/train, name=exp_0_0, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-135-g9dd0ad3 Python-3.9.16 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# ...

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_0.yaml --name exp_0_0
# Out:
# train: weights=yolov5s.pt, cfg=, data=../custom_data.yaml, hyp=../data/hyps/hyp_0_0.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../runs/train, name=exp_0_0, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-135-g9dd0ad3 Python-3.9.16 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# ...

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_1.yaml --name exp_0_1

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_2.yaml --name exp_0_2

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_3.yaml --name exp_0_3

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_4.yaml --name exp_0_4

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_5.yaml --name exp_0_5

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_0_6.yaml --name exp_0_6

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_0.yaml --name exp_1_0

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_1.yaml --name exp_1_1

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_2.yaml --name exp_1_2

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_3.yaml --name exp_1_3

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_4.yaml --name exp_1_4

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_5.yaml --name exp_1_5

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_1_6.yaml --name exp_1_6

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_0.yaml --name exp_2_0

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_1.yaml --name exp_2_1

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_2.yaml --name exp_2_2

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_3.yaml --name exp_2_3

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_4.yaml --name exp_2_4

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_5.yaml --name exp_2_5

# %%
# %%python train.py --img 640 --batch 16 --epochs 100 --project ../runs/train --weights yolov5s.pt --data ../custom_data.yaml --hyp ../data/hyps/hyp_2_6.yaml --name exp_2_6
